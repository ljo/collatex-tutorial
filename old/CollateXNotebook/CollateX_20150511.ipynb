# %%
from collatex import *

# %%
collation = Collation()
collation.add_plain_witness( "A", "The quick brown fox jumped over the lazy dog.")
collation.add_plain_witness( "B", "The brown fox jumped over the dog." )
collation.add_plain_witness( "C", "The bad fox jumped over the lazy dog." )
alignment_table = collate(collation, layout='vertical')

# %%
print( alignment_table )
# Out:
# whatever

# %%
graph = collate( collation, output="svg" )

# %%
collation = Collation()
witness_A = open( "./CollateX/fixtures/Rijmb_Judit_Aaa_TEXT.txt" ).read()
witness_B = open( "./CollateX/fixtures/Rijmb_Judit_Bbb_TEXT.txt" ).read()
witness_C = open( "./CollateX/fixtures/Rijmb_Judit_Ccc_TEXT.txt" ).read()
witness_D = open( "./CollateX/fixtures/Rijmb_Judit_Ddd_TEXT.txt" ).read()
collation.add_plain_witness( "A", witness_A )
collation.add_plain_witness( "B", witness_B )
collation.add_plain_witness( "C", witness_C )
collation.add_plain_witness( "D", witness_D )

# %%
print( witness_A )
# Out:
# Judits ieeste gaet hier an
# Van liue wijf van herten man
# UErstaet Nu wel Na cyrus doot.
# Wart een arfaxat here groot.
# Die ueste gathamus de stede
# Die staet in dat lant van mede
# Ommedat hi wilde moghendelike
# Winnen van Meden tconincrike
# Nabugodonosor cambises
# Cyrus sone verdiende des
# hem gaf sijn uader eer hi bleef doot
# Niniue die goede stede groot
# Ende van assyrien dat lant
# .xij. iaer dats wel bekant
# Droech hi crone voor cyrus doot
# die gaf arfaxat wederstoot
# ende sloeghene doot ende wan tlant
# Ende doe hi hadde in sine hant
# beide persen ende meden
# ende aldes uader moeghentheden
# verhief hi sijn herte daerna
# ende hi sendde in cilicia
# ende in al die lande omtrent hem
# Al toter stat van iherusalem
# Ende eeschde chens ende gauel mede
# meer dan ye sijn vader dede
# Ende si ontseiden hem alle gavel
# doe nam hi sinen conincstauel
# Holofornese ende gheboot
# Dat hi name sijn here groot
# ende hi niemens ooc uermede
# ...

# %%
print( witness_B )
# Out:
# Judits ieeste gaet hier an
# van liue wijf van herten man
# verstaet nv wel van cyrus doet
# wart een arfaxat here groet
# ende veste gathamus die stede
# die staet in dat lant van mede
# omdat hi wilde mogendelike

# %%
alignment_table = collate(collation, layout='vertical')

# %%
print( alignment_table )
# Out:
# +------------------+-----------------+-------------------+-----------------+
# |        A         |        B        |         C         |        D        |
# +------------------+-----------------+-------------------+-----------------+
# |  Judits ieeste   |  Judits ieeste  |   Judiths geeste  |  Judits ieeste  |
# +------------------+-----------------+-------------------+-----------------+
# |   gaet hier an   |   gaet hier an  |    gaet hier an   |   gaet hier an  |
# +------------------+-----------------+-------------------+-----------------+
# |        -         |       van       |         .         |        -        |
# +------------------+-----------------+-------------------+-----------------+
# |       Van        |        -        |        Van        |       Van       |
# +------------------+-----------------+-------------------+-----------------+
# |  liue wijf van   |  liue wijf van  |   liue wijf van   |  liue wijf van  |
# ...

# %%
graph = collate( collation, output="svg" )
